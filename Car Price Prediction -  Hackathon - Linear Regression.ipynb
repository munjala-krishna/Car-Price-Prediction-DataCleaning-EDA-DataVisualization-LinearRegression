# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Training_Data_Set.csv')

# %%
df.head(5)
# Out:
#       Id   Maker    model   Location  Distance       Owner Type  \
# 0  25001   skoda  octavia  Ahmedabad        NaN          Second
# 1  25002    fiat    panda  Ahmedabad    27750.0           Third
# 2  25003     bmw       x1  Hyderabad    46000.0           Third
# 3  25004  nissan     juke     Mumbai    43949.0           Third
# 4  25005     bmw       x5     Jaipur    59524.0  Fourth & Above
#
#    manufacture_year  Age of car  engine_displacement  engine_power body_type  \
# 0              1964          55                 1964         147.0   compact
# 1              2012           7                 1242          51.0       NaN
# 2              2014           5                 1995         105.0       NaN
# 3              2011           8                 1618         140.0       NaN
# 4              2012           7                 2993         180.0       NaN
#
#    Vroom Audit Rating transmission  door_count  seat_count fuel_type  \
# ...

# %%
df.shape
# Out:
# (53515, 17)

# %%
df.dtypes
# Out:
# Id                       int64
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# manufacture_year         int64
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# body_type               object
# Vroom Audit Rating       int64
# transmission            object
# door_count             float64
# seat_count             float64
# fuel_type               object
# Price                  float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id                         0
# Maker                      0
# model                      0
# Location                   0
# Distance                1211
# Owner Type                 0
# manufacture_year           0
# Age of car                 0
# engine_displacement        0
# engine_power            1439
# body_type              49379
# Vroom Audit Rating         0
# transmission               0
# door_count              7534
# seat_count              8511
# fuel_type                  0
# Price                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53515 entries, 0 to 53514
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   53515 non-null  int64
#  1   Maker                53515 non-null  object
#  2   model                53515 non-null  object
#  3   Location             53515 non-null  object
#  4   Distance             52304 non-null  float64
#  5   Owner Type           53515 non-null  object
#  6   manufacture_year     53515 non-null  int64
#  7   Age of car           53515 non-null  int64
#  8   engine_displacement  53515 non-null  int64
#  9   engine_power         52076 non-null  float64
#  10  body_type            4136 non-null   object
#  11  Vroom Audit Rating   53515 non-null  int64
#  12  transmission         53515 non-null  object
#  13  door_count           45981 non-null  float64
#  14  seat_count           45004 non-null  float64
# ...

# %%
df.head(2)
# Out:
#       Id  Maker    model   Location  Distance  Owner Type  manufacture_year  \
# 0  25001  skoda  octavia  Ahmedabad        NaN     Second              1964
# 1  25002   fiat    panda  Ahmedabad    27750.0      Third              2012
#
#    Age of car  engine_displacement  engine_power body_type  \
# 0          55                 1964         147.0   compact
# 1           7                 1242          51.0       NaN
#
#    Vroom Audit Rating transmission  door_count  seat_count fuel_type  \
# 0                   8          man         NaN         NaN    petrol
# 1                   6          man         4.0         4.0    petrol
#
#        Price
# 0  543764.25
# 1  401819.25

# %%
print(df.isnull().sum()/len(df)*100)
# Out:
# Id                      0.000000
# Maker                   0.000000
# model                   0.000000
# Location                0.000000
# Distance                2.262917
# Owner Type              0.000000
# manufacture_year        0.000000
# Age of car              0.000000
# engine_displacement     0.000000
# engine_power            2.688966
# body_type              92.271326
# Vroom Audit Rating      0.000000
# transmission            0.000000
# door_count             14.078296
# seat_count             15.903952
# fuel_type               0.000000
# Price                   0.000000
# dtype: float64

# %%
df['body_type'].unique()
# Out:
# array(['compact', nan, 'van'], dtype=object)

# %%
df['body_type'].value_counts()/len(df)*100
# Out:
# body_type
# compact    7.711856
# van        0.016818
# Name: count, dtype: float64

# %%
df['door_count'].unique()
# Out:
# array([nan,  4.,  5.,  2.,  3.,  1.,  6.])

# %%
df['door_count'].value_counts()/len(df)*100
# Out:
# door_count
# 4.0    63.174811
# 5.0    14.257685
# 2.0     8.124825
# 3.0     0.345697
# 6.0     0.014949
# 1.0     0.003737
# Name: count, dtype: float64

# %%
df['seat_count'].unique()
# Out:
# array([nan,  4.,  5.,  2.,  3.,  7.,  6.,  1.,  9.,  8.])

# %%
df['seat_count'].value_counts()/len(df)*100
# Out:
# seat_count
# 5.0    72.547884
# 4.0     8.347192
# 7.0     1.592077
# 2.0     1.354760
# 3.0     0.203681
# 6.0     0.042979
# 9.0     0.003737
# 1.0     0.001869
# 8.0     0.001869
# Name: count, dtype: float64

# %%
df['manufacture_year'].value_counts()/len(df)*100
# Out:
# manufacture_year
# 2015    23.146781
# 2012    11.678969
# 2011     9.229188
# 2014     9.113333
# 2010     7.061572
# 2009     5.445202
# 2013     5.437728
# 2008     5.342427
# 2007     5.306923
# 2006     3.770905
# 2005     3.186023
# 2004     2.505839
# 2003     1.765860
# 2001     1.403345
# 2002     1.388396
# 2000     1.358498
# 1999     1.009063
# 1998     0.584883
# 2016     0.383070
# 1997     0.263478
# 1996     0.140148
# 1994     0.069139
# 1991     0.059796
# 1995     0.057928
# 1993     0.041110
# 1992     0.039241
# 1990     0.031767
# 1989     0.024292
# 1968     0.024292
# 1988     0.018686
# 1950     0.011212
# 1984     0.011212
# 1985     0.009343
# 1973     0.007475
# 1982     0.007475
# 1986     0.007475
# 1980     0.007475
# 1983     0.005606
# 1971     0.005606
# 1972     0.003737
# 1987     0.003737
# 1962     0.003737
# 1964     0.003737
# 1966     0.003737
# 1956     0.001869
# 1952     0.001869
# 1955     0.001869
# 1969     0.001869
# 1960     0.001869
# ...

# %%
df['Id'].nunique()
# Out:
# 53515

# %%
df['Maker'].value_counts()/len(df)*100
# Out:
# Maker
# skoda       40.293376
# toyota      14.650098
# audi        13.689620
# bmw         13.413062
# nissan      10.249463
# hyundai      4.185742
# fiat         3.447632
# maserati     0.071008
# Name: count, dtype: float64

# %%
df['model'].value_counts()/len(df)*100
# Out:
# model
# octavia     23.580305
# superb       5.970289
# yaris        5.934785
# qashqai      5.333084
# x3           5.192937
# x1           4.522097
# i30          3.825096
# q5           3.810147
# x5           3.698029
# yeti         3.546669
# panda        3.305615
# q3           3.243950
# coupe        3.195366
# micra        3.131832
# auris        3.113146
# avensis      2.825376
# aygo         2.776792
# rapid        2.632907
# roomster     2.470335
# q7           2.326451
# citigo       2.092871
# juke         1.784546
# tt           1.687377
# Name: count, dtype: float64

# %%
df['Location'].value_counts()
# Out:
# Location
# Coimbatore    4976
# Kochi         4969
# Bangalore     4878
# Jaipur        4870
# Kolkata       4868
# Pune          4862
# Mumbai        4860
# Chennai       4834
# Delhi         4824
# Hyderabad     4804
# Ahmedabad     4770
# Name: count, dtype: int64

# %%
df['Owner Type'].value_counts()
# Out:
# Owner Type
# First             13406
# Third             13395
# Second            13365
# Fourth & Above    13349
# Name: count, dtype: int64

# %%
df['transmission'].value_counts()
# Out:
# transmission
# man     36734
# auto    16781
# Name: count, dtype: int64

# %%
df['fuel_type'].value_counts()
# Out:
# fuel_type
# diesel    27559
# petrol    25956
# Name: count, dtype: int64

# %%
df1 = df.drop(columns=['Id', 'manufacture_year', 'door_count', 'seat_count', 'body_type'])

# %%
df1.head(2)
# Out:
#    Maker    model   Location  Distance  Owner Type  Age of car  \
# 0  skoda  octavia  Ahmedabad        NaN     Second          55
# 1   fiat    panda  Ahmedabad    27750.0      Third           7
#
#    engine_displacement  engine_power  Vroom Audit Rating transmission  \
# 0                 1964         147.0                   8          man
# 1                 1242          51.0                   6          man
#
#   fuel_type      Price
# 0    petrol  543764.25
# 1    petrol  401819.25

# %%
df1.isnull().sum()/len(df)*100
# Out:
# Maker                  0.000000
# model                  0.000000
# Location               0.000000
# Distance               2.262917
# Owner Type             0.000000
# Age of car             0.000000
# engine_displacement    0.000000
# engine_power           2.688966
# Vroom Audit Rating     0.000000
# transmission           0.000000
# fuel_type              0.000000
# Price                  0.000000
# dtype: float64

# %%
df1.describe()
# Out:
#           Distance     Age of car  engine_displacement  engine_power  \
# count  5.230400e+04  53515.000000         53515.000000  52076.000000
# mean   9.454626e+04      8.591890          1904.049014    100.448345
# std    2.755617e+05      4.650322          1496.564596     45.330622
# min    0.000000e+00      3.000000            14.000000     10.000000
# 25%    1.549000e+04      5.000000          1395.000000     73.000000
# 50%    6.552000e+04      8.000000          1896.000000     91.000000
# 75%    1.356410e+05     11.000000          1995.000000    125.000000
# max    9.899800e+06     85.000000         32000.000000    896.000000
#
#        Vroom Audit Rating         Price
# count        53515.000000  5.351500e+04
# mean             5.998374  1.098084e+06
# std              1.418336  8.441565e+05
# min              4.000000  3.000000e+00
# 25%              5.000000  5.051812e+05
# 50%              6.000000  8.854552e+05
# 75%              7.000000  1.477829e+06
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(df1['engine_power'])
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\3510823175.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['engine_power'])
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df1.head(2)
# Out:
#    Maker    model   Location  Distance  Owner Type  Age of car  \
# 0  skoda  octavia  Ahmedabad        NaN     Second          55
# 1   fiat    panda  Ahmedabad    27750.0      Third           7
#
#    engine_displacement  engine_power  Vroom Audit Rating transmission  \
# 0                 1964         147.0                   8          man
# 1                 1242          51.0                   6          man
#
#   fuel_type      Price
# 0    petrol  543764.25
# 1    petrol  401819.25

# %%
df1.dtypes
# Out:
# Maker                   object
# model                   object
# Location                object
# Distance               float64
# Owner Type              object
# Age of car               int64
# engine_displacement      int64
# engine_power           float64
# Vroom Audit Rating       int64
# transmission            object
# fuel_type               object
# Price                  float64
# dtype: object

# %%
sns.distplot(df1['Distance '])
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\3937533003.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['Distance '])
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df1.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Distance ', 'Owner Type', 'Age of car',
#        'engine_displacement', 'engine_power', 'Vroom Audit Rating',
#        'transmission', 'fuel_type', 'Price'],
#       dtype='object')

# %%
plt.hist(df1['Distance '], density=True)
# Out:
# (array([1.00724385e-06, 9.27000382e-10, 2.31750096e-10, 3.86250159e-10,
#         5.79375239e-11, 3.66937651e-10, 1.15875048e-10, 3.09000127e-10,
#         3.47625143e-10, 1.35187556e-10]),
#  array([      0.,  989980., 1979960., 2969940., 3959920., 4949900.,
#         5939880., 6929860., 7919840., 8909820., 9899800.]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df1['Distance '])
# Out:
# <Axes: >

# %%
sns.boxplot(df1['engine_power'])
# Out:
# <Axes: >

# %%
plt.hist(df1['engine_power'], density = True)
# Out:
# (array([6.11473906e-03, 4.65416321e-03, 4.65979831e-04, 3.25102208e-05,
#         1.79889888e-05, 6.50204416e-07, 2.16734805e-07, 0.00000000e+00,
#         0.00000000e+00, 4.33469610e-07]),
#  array([ 10. ,  98.6, 187.2, 275.8, 364.4, 453. , 541.6, 630.2, 718.8,
#         807.4, 896. ]),
#  <BarContainer object of 10 artists>)

# %%
df1['Distance '] = df1['Distance '].fillna(df1['Distance '].median())

# %%
df1['engine_power'] = df1['engine_power'].fillna(df1['engine_power'].median())

# %%
df1.isnull().sum()
# Out:
# Maker                  0
# model                  0
# Location               0
# Distance               0
# Owner Type             0
# Age of car             0
# engine_displacement    0
# engine_power           0
# Vroom Audit Rating     0
# transmission           0
# fuel_type              0
# Price                  0
# dtype: int64

# %%
plt.hist(df1['Distance '])
# Out:
# (array([5.3366e+04, 4.8000e+01, 1.2000e+01, 2.0000e+01, 3.0000e+00,
#         1.9000e+01, 6.0000e+00, 1.6000e+01, 1.8000e+01, 7.0000e+00]),
#  array([      0.,  989980., 1979960., 2969940., 3959920., 4949900.,
#         5939880., 6929860., 7919840., 8909820., 9899800.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df1['engine_power'])
# Out:
# (array([2.9652e+04, 2.1474e+04, 2.1500e+03, 1.5000e+02, 8.3000e+01,
#         3.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([ 10. ,  98.6, 187.2, 275.8, 364.4, 453. , 541.6, 630.2, 718.8,
#         807.4, 896. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.boxplot(df1)
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.scatter(df1['Distance '], df1['Price'])

# %%
Q1 = df1['Distance '].quantile(0.25)
Q3 = df1['Distance '].quantile(0.75)
IQR = Q3 - Q1

# %%
print(Q1, Q3, IQR)
# Out:
# 16507.0 133304.0 116797.0

# %%
x =np.where((df1['Distance '] < Q1-1.5*IQR) | (df1['Distance '] > Q3 +1.5*IQR))

# %%
print(x)
# Out:
# (array([  194,   235,   327,   408,   449,   557,   618,   644,   694,
#          827,   857,   970,  1053,  1065,  1070,  1075,  1347,  1490,
#         1562,  1589,  2130,  2202,  2372,  2457,  2628,  2723,  2758,
#         3001,  3109,  3258,  3262,  3348,  3574,  3650,  3679,  3720,
#         3828,  3855,  3971,  4051,  4068,  4248,  4279,  4470,  4482,
#         4694,  4809,  4990,  5084,  5097,  5162,  5227,  5274,  5384,
#         5688,  5692,  5701,  5759,  5788,  5814,  5904,  5921,  5923,
#         5939,  5952,  5958,  5982,  6119,  6142,  6258,  6266,  6342,
#         6395,  6432,  6436,  6473,  6512,  6568,  6640,  6698,  6714,
#         6726,  6929,  7031,  7095,  7279,  7304,  7306,  7339,  7364,
#         7458,  7540,  7650,  7722,  7815,  7837,  7886,  7906,  8071,
#         8101,  8414,  8543,  8561,  8643,  8752,  8859,  8933,  9029,
#         9081,  9101,  9113,  9209,  9225,  9237,  9281,  9464,  9490,
# ...

# %%
len(x[0])
# Out:
# 595

# %%
df2 = df1.copy()

# %%
df2.head(2)
# Out:
#    Maker    model   Location  Distance  Owner Type  Age of car  \
# 0  skoda  octavia  Ahmedabad    65520.0     Second          55
# 1   fiat    panda  Ahmedabad    27750.0      Third           7
#
#    engine_displacement  engine_power  Vroom Audit Rating transmission  \
# 0                 1964         147.0                   8          man
# 1                 1242          51.0                   6          man
#
#   fuel_type      Price
# 0    petrol  543764.25
# 1    petrol  401819.25

# %%
df2.shape
# Out:
# (53515, 12)

# %%
lower =  (Q1-1.5*IQR)
upper =  (Q3+1.5*IQR)

for i in np.where(df2['Distance '] < lower )[0]:
    df2['Distance '] = lower
    
for i in np.where(df2['Distance '] > upper)[0]:
    df2['Distance '] = upper

# %%
sns.boxplot(df1)
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df1_numeric_features = df1.select_dtypes(include =[np.number])
df1_numeric_features.columns
# Out:
# Index(['Distance ', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'Price'],
#       dtype='object')

# %%
df1_categorical_features = df1.select_dtypes(include =object)
df1_categorical_features.columns
# Out:
# Index(['Maker', 'model', 'Location', 'Owner Type', 'transmission',
#        'fuel_type'],
#       dtype='object')

# %%
df1_categorical_features.columns.values
# Out:
# array(['Maker', 'model', 'Location', 'Owner Type', 'transmission',
#        'fuel_type'], dtype=object)

# %%
for col in df1_categorical_features.columns.values:
    dummy_encoded_variables = pd.get_dummies(df1_categorical_features[col], prefix = col, drop_first = True)
    df1_categorical_features = pd.concat([df1_categorical_features, dummy_encoded_variables], axis = 1)
    df1_categorical_features.drop([col], axis=1, inplace = True)

# %%
df1_dummy = pd.concat([df1_numeric_features, df1_categorical_features], axis=1)

# %%
df1_dummy.head()
# Out:
#    Distance   Age of car  engine_displacement  engine_power  \
# 0    65520.0          55                 1964         147.0
# 1    27750.0           7                 1242          51.0
# 2    46000.0           5                 1995         105.0
# 3    43949.0           8                 1618         140.0
# 4    59524.0           7                 2993         180.0
#
#    Vroom Audit Rating       Price  Maker_bmw  Maker_fiat  Maker_hyundai  \
# 0                   8   543764.25      False       False          False
# 1                   6   401819.25      False        True          False
# 2                   7  2392855.50       True       False          False
# 3                   7   958606.50      False       False          False
# 4                   7  3085561.50       True       False          False
#
#    Maker_maserati  ...  Location_Jaipur  Location_Kochi  Location_Kolkata  \
# 0           False  ...            False           False             False
# ...

# %%
x =df1_dummy.columns.values

# %%
len(x)
# Out:
# 50

# %%
x
# Out:
# array(['Distance ', 'Age of car', 'engine_displacement', 'engine_power',
#        'Vroom Audit Rating', 'Price', 'Maker_bmw', 'Maker_fiat',
#        'Maker_hyundai', 'Maker_maserati', 'Maker_nissan', 'Maker_skoda',
#        'Maker_toyota', 'model_avensis', 'model_aygo', 'model_citigo',
#        'model_coupe', 'model_i30', 'model_juke', 'model_micra',
#        'model_octavia', 'model_panda', 'model_q3', 'model_q5', 'model_q7',
#        'model_qashqai', 'model_rapid', 'model_roomster', 'model_superb',
#        'model_tt', 'model_x1', 'model_x3', 'model_x5', 'model_yaris',
#        'model_yeti', 'Location_Bangalore', 'Location_Chennai',
#        'Location_Coimbatore', 'Location_Delhi', 'Location_Hyderabad',
#        'Location_Jaipur', 'Location_Kochi', 'Location_Kolkata',
#        'Location_Mumbai', 'Location_Pune', 'Owner Type_Fourth & Above',
#        'Owner Type_Second', 'Owner Type_Third', 'transmission_man',
#        'fuel_type_petrol'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
df1_train, df1_test = train_test_split(df1_dummy, random_state = 1)
print(df1_train.shape)
print(df1_test.shape)
# Out:
# (40136, 50)
# (13379, 50)

# %%
x_train1 = df1_train.drop(['Price'], axis=1)
y_train1 = df1_train['Price']

lr1 = LinearRegression()
lr1.fit(x_train1, y_train1)

pd.DataFrame({'attribute':x_train1.columns, 'coeff':lr1.coef_})
# Out:
#                     attribute          coeff
# 0                   Distance       -0.169129
# 1                  Age of car  -84183.835135
# 2         engine_displacement      -6.251544
# 3                engine_power    4155.172969
# 4          Vroom Audit Rating     783.102961
# 5                   Maker_bmw  101337.406713
# 6                  Maker_fiat  349667.424343
# 7               Maker_hyundai -779863.440561
# 8              Maker_maserati  125635.718122
# 9                Maker_nissan -335872.353461
# 10                Maker_skoda -449944.022500
# 11               Maker_toyota -498418.662710
# 12              model_avensis   99100.395573
# 13                 model_aygo -229236.978228
# 14               model_citigo -372116.139334
# 15                model_coupe  307167.556211
# 16                  model_i30  148585.690828
# 17                 model_juke -227275.949076
# 18                model_micra -146969.076013
# 19              model_octavia   24736.257399
# ...

# %%
x_test1 = df1_test.drop(['Price'], axis=1)

y_test1 = df1_test['Price']

y_pred_test1 = lr1.predict(x_test1)

rmsq_test1 = mean_squared_error(y_test1, y_pred_test1, squared = False)

# %%
rmsq_test1
# Out:
# 423413.0247575809

# %%
y_pred_train1 = lr1.predict(x_train1)

rmsq_train1 = mean_squared_error(y_train1, y_pred_train1, squared = False)

rmsq_train1
# Out:
# 447809.8748275384

# %%
df1_numeric_features.corr()
# Out:
#                      Distance   Age of car  engine_displacement  engine_power  \
# Distance              1.000000    0.217804             0.091652      0.009684
# Age of car            0.217804    1.000000             0.090401     -0.048981
# engine_displacement   0.091652    0.090401             1.000000      0.312616
# engine_power          0.009684   -0.048981             0.312616      1.000000
# Vroom Audit Rating   -0.006235   -0.003985            -0.005828     -0.001641
# Price                -0.155366   -0.506707             0.162072      0.620668
#
#                      Vroom Audit Rating     Price
# Distance                      -0.006235 -0.155366
# Age of car                    -0.003985 -0.506707
# engine_displacement           -0.005828  0.162072
# engine_power                  -0.001641  0.620668
# Vroom Audit Rating             1.000000  0.005109
# Price                          0.005109  1.000000

# %%
corr = df1_numeric_features.corr()
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df1_categorical_features1 = df1.select_dtypes(include = object)

# %%
df1_categorical_features1.head(2)
# Out:
#    Maker    model   Location Owner Type transmission fuel_type
# 0  skoda  octavia  Ahmedabad     Second          man    petrol
# 1   fiat    panda  Ahmedabad      Third          man    petrol

# %%
sns.pairplot(df1)
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
plt.hist(df1.Price)
# Out:
# (array([4.845e+04, 4.743e+03, 2.950e+02, 2.000e+01, 4.000e+00, 1.000e+00,
#         0.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([3.00000000e+00, 2.21208023e+06, 4.42415745e+06, 6.63623468e+06,
#         8.84831190e+06, 1.10603891e+07, 1.32724664e+07, 1.54845436e+07,
#         1.76966208e+07, 1.99086980e+07, 2.21207752e+07]),
#  <BarContainer object of 10 artists>)

# %%
df1.describe()
# Out:
#           Distance     Age of car  engine_displacement  engine_power  \
# count  5.351500e+04  53515.000000         53515.000000  53515.000000
# mean   9.388942e+04      8.591890          1904.049014    100.194282
# std    2.724601e+05      4.650322          1496.564596     44.743107
# min    0.000000e+00      3.000000            14.000000     10.000000
# 25%    1.650700e+04      5.000000          1395.000000     74.000000
# 50%    6.552000e+04      8.000000          1896.000000     91.000000
# 75%    1.333040e+05     11.000000          1995.000000    125.000000
# max    9.899800e+06     85.000000         32000.000000    896.000000
#
#        Vroom Audit Rating         Price
# count        53515.000000  5.351500e+04
# mean             5.998374  1.098084e+06
# std              1.418336  8.441565e+05
# min              4.000000  3.000000e+00
# 25%              5.000000  5.051812e+05
# 50%              6.000000  8.854552e+05
# 75%              7.000000  1.477829e+06
# ...

# %%
df1.describe(include = object)
# Out:
#         Maker    model    Location Owner Type transmission fuel_type
# count   53515    53515       53515      53515        53515     53515
# unique      8       23          11          4            2         2
# top     skoda  octavia  Coimbatore      First          man    diesel
# freq    21563    12619        4976      13406        36734     27559

# %%
sns.countplot(data=df1, x= 'Maker')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Maker', ylabel='count'>

# %%
sns.countplot(data=df1, x= 'model')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='model', ylabel='count'>

# %%
sns.countplot(data=df1, x= 'Location')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Location', ylabel='count'>

# %%
sns.countplot(data=df1, x= 'Owner Type')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Owner Type', ylabel='count'>

# %%
sns.countplot(data=df1, x= 'transmission')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(data=df1, x= 'fuel_type')
# Out:
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='fuel_type', ylabel='count'>

# %%
df1.groupby(['fuel_type'])['Price'].mean()
# Out:
# fuel_type
# diesel    1.357251e+06
# petrol    8.229106e+05
# Name: Price, dtype: float64

# %%
df1.groupby(['transmission'])['Price'].mean()
# Out:
# transmission
# auto    1.721609e+06
# man     8.132418e+05
# Name: Price, dtype: float64

# %%
df1.groupby(['Owner Type'])['Price'].mean()
# Out:
# Owner Type
# First             1.109406e+06
# Fourth & Above    1.093697e+06
# Second            1.084591e+06
# Third             1.104585e+06
# Name: Price, dtype: float64

# %%
df1.groupby(['Location'])['Price'].mean()
# Out:
# Location
# Ahmedabad     1.084637e+06
# Bangalore     1.095504e+06
# Chennai       1.114452e+06
# Coimbatore    1.115280e+06
# Delhi         1.107027e+06
# Hyderabad     1.097899e+06
# Jaipur        1.097340e+06
# Kochi         1.080597e+06
# Kolkata       1.111983e+06
# Mumbai        1.084713e+06
# Pune          1.089362e+06
# Name: Price, dtype: float64

# %%
df1.groupby(['model'])['Price'].mean()
# Out:
# model
# auris       1.007341e+06
# avensis     6.939379e+05
# aygo        5.217669e+05
# citigo      6.040203e+05
# coupe       1.606849e+06
# i30         8.062681e+05
# juke        1.016066e+06
# micra       3.733901e+05
# octavia     6.936200e+05
# panda       4.317296e+05
# q3          2.108287e+06
# q5          2.217625e+06
# q7          2.700675e+06
# qashqai     1.212997e+06
# rapid       9.339825e+05
# roomster    5.432577e+05
# superb      1.122929e+06
# tt          1.600868e+06
# x1          1.627981e+06
# x3          1.837825e+06
# x5          1.974800e+06
# yaris       5.859161e+05
# yeti        1.150855e+06
# Name: Price, dtype: float64

# %%
df1.groupby(['Maker'])['Price'].mean()
# Out:
# Maker
# audi        2.123176e+06
# bmw         1.804843e+06
# fiat        4.333561e+05
# hyundai     7.678909e+05
# maserati    2.039815e+06
# nissan      9.221584e+05
# skoda       7.993109e+05
# toyota      6.841427e+05
# Name: Price, dtype: float64

# %%
df1.head(2)
# Out:
#    Maker    model   Location  Distance  Owner Type  Age of car  \
# 0  skoda  octavia  Ahmedabad    65520.0     Second          55
# 1   fiat    panda  Ahmedabad    27750.0      Third           7
#
#    engine_displacement  engine_power  Vroom Audit Rating transmission  \
# 0                 1964         147.0                   8          man
# 1                 1242          51.0                   6          man
#
#   fuel_type      Price
# 0    petrol  543764.25
# 1    petrol  401819.25

# %%
df3 = df1.drop(['Location', 'Distance ', 'Owner Type','engine_displacement', 'Vroom Audit Rating'], axis=1)

# %%
df3.head(2)
# Out:
#    Maker    model  Age of car  engine_power transmission fuel_type      Price
# 0  skoda  octavia          55         147.0          man    petrol  543764.25
# 1   fiat    panda           7          51.0          man    petrol  401819.25

# %%
df3.isnull().sum()
# Out:
# Maker           0
# model           0
# Age of car      0
# engine_power    0
# transmission    0
# fuel_type       0
# Price           0
# dtype: int64

# %%
sns.boxplot(df3['engine_power'])
# Out:
# <Axes: >

# %%
# df1.groupby(['model'])['engine_power'].agg(['min','mean', 'median','max'])
df1.groupby(['transmission'])['engine_power'].describe().transpose()
# Out:
# transmission          auto           man
# count         16781.000000  36734.000000
# mean            133.658602     84.906953
# std              53.577975     29.323840
# min              10.000000     10.000000
# 25%             103.000000     66.000000
# 50%             130.000000     80.000000
# 75%             171.000000    103.000000
# max             533.000000    896.000000

# %%
df3.head()
# Out:
#     Maker    model  Age of car  engine_power transmission fuel_type  \
# 0   skoda  octavia          55         147.0          man    petrol
# 1    fiat    panda           7          51.0          man    petrol
# 2     bmw       x1           5         105.0         auto    diesel
# 3  nissan     juke           8         140.0          man    petrol
# 4     bmw       x5           7         180.0         auto    diesel
#
#         Price
# 0   543764.25
# 1   401819.25
# 2  2392855.50
# 3   958606.50
# 4  3085561.50

# %%
df3_numeric_features = df3.select_dtypes(include =[np.number])
df3_numeric_features.columns
# Out:
# Index(['Age of car', 'engine_power', 'Price'], dtype='object')

# %%
df3_categorical_features = df3.select_dtypes(include =object)
df3_categorical_features.columns
# Out:
# Index(['Maker', 'model', 'transmission', 'fuel_type'], dtype='object')

# %%
df3_categorical_features.columns.values
# Out:
# array(['Maker', 'model', 'transmission', 'fuel_type'], dtype=object)

# %%
for col in df3_categorical_features.columns.values:
    dummy_encoded_variables3 = pd.get_dummies(df3_categorical_features[col], prefix = col, drop_first = True)
    df3_categorical_features = pd.concat([df3_categorical_features, dummy_encoded_variables3], axis = 1)
    df3_categorical_features.drop([col], axis=1, inplace = True)

# %%
df3_dummy = pd.concat([df3_numeric_features, df3_categorical_features], axis=1)

# %%
df3_dummy.head()
# Out:
#    Age of car  engine_power       Price  Maker_bmw  Maker_fiat  Maker_hyundai  \
# 0          55         147.0   543764.25      False       False          False
# 1           7          51.0   401819.25      False        True          False
# 2           5         105.0  2392855.50       True       False          False
# 3           8         140.0   958606.50      False       False          False
# 4           7         180.0  3085561.50       True       False          False
#
#    Maker_maserati  Maker_nissan  Maker_skoda  Maker_toyota  ...  \
# 0           False         False         True         False  ...
# 1           False         False        False         False  ...
# 2           False         False        False         False  ...
# 3           False          True        False         False  ...
# 4           False         False        False         False  ...
#
#    model_roomster  model_superb  model_tt  model_x1  model_x3  model_x5  \
# ...

# %%
x3 =df3_dummy.columns.values
len(x3)
# Out:
# 34

# %%
df3_train, df3_test = train_test_split(df3_dummy, random_state = 1)
print(df3_train.shape)
print(df3_test.shape)
# Out:
# (40136, 34)
# (13379, 34)

# %%
x_train3 = df3_train.drop(['Price'], axis=1)
y_train3 = df3_train['Price']

# %%
lr3 = LinearRegression()
lr3.fit(x_train3, y_train3)
pd.DataFrame({'attribute':x_train3.columns, 'coeff':lr3.coef_})
# Out:
#            attribute          coeff
# 0         Age of car  -86319.659966
# 1       engine_power    4138.201514
# 2          Maker_bmw   98438.450342
# 3         Maker_fiat  380002.339994
# 4      Maker_hyundai -777087.477246
# 5     Maker_maserati  134414.636679
# 6       Maker_nissan -328882.213718
# 7        Maker_skoda -449272.913432
# 8       Maker_toyota -492275.718688
# 9      model_avensis   91413.730964
# 10        model_aygo -223460.535921
# 11      model_citigo -364279.437269
# 12       model_coupe  312501.013381
# 13         model_i30  151245.691933
# 14        model_juke -225394.258731
# 15       model_micra -139854.756691
# 16     model_octavia   17908.020857
# 17       model_panda -952257.586296
# 18          model_q3  325511.634869
# 19          model_q5  402428.622464
# 20          model_q7  722596.691612
# 21     model_qashqai   36366.801704
# 22       model_rapid -153076.796594
# 23    model_roomster -105777.442529
# 24      model_superb   66017.736195
# ...

# %%
x_test3 = df3_test.drop(['Price'], axis=1)
y_test3 = df3_test['Price']
y_pred_test3 = lr3.predict(x_test3)
rmsq_test3 = mean_squared_error(y_test3, y_pred_test3, squared = False)

# %%
rmsq_test3
# Out:
# 425632.6971366801

# %%
y_pred_train3 = lr3.predict(x_train3)
rmsq_train3 = mean_squared_error(y_train3, y_pred_train3, squared = False)
rmsq_train3
# Out:
# 450272.1066564737

# %%
df5 = df1.drop(['Maker','Location', 'Distance ', 'Owner Type','engine_displacement', 'Vroom Audit Rating'], axis=1)

# %%
df5.head(2)
# Out:
#      model  Age of car  engine_power transmission fuel_type      Price
# 0  octavia          55         147.0          man    petrol  543764.25
# 1    panda           7          51.0          man    petrol  401819.25

# %%
sns.boxplot(df5['Age of car'])
# Out:
# <Axes: >

# %%
Q1 = df5['engine_power'].quantile(0.25)
Q3 = df5['engine_power'].quantile(0.75)
IQR = Q3 - Q1
print(Q1, Q3, IQR)
# Out:
# 74.0 125.0 51.0

# %%
lower =  (Q1-1.5*IQR)
upper =  (Q3+1.5*IQR)
for i in np.where(df5['engine_power'] < lower )[0]:
    df5['engine_power'][i]= lower
for i in np.where(df5['engine_power'] > upper)[0]:
    df5['engine_power'][i] = upper
df5['engine_power'].describe()
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1238523346.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['engine_power'][i] = upper
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1238523346.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['engine_power'][i] = upper
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1238523346.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sns.boxplot(df5['engine_power'])
# Out:
# <Axes: >

# %%
sns.distplot(df5['engine_power'])
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1779445488.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5['engine_power'])
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
Q1 = df5['Age of car'].quantile(0.25)
Q3 = df5['Age of car'].quantile(0.75)
IQR = Q3 - Q1
print(Q1, Q3, IQR)
# Out:
# 5.0 11.0 6.0

# %%
lower =  (Q1-1.5*IQR)
upper =  (Q3+1.5*IQR)
for i in np.where(df5['Age of car'] < lower )[0]:
    df5['Age of car'][i]= lower
for i in np.where(df5['Age of car'] > upper)[0]:
    df5['Age of car'][i] = upper
df5['Age of car'].describe()
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1858429955.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Age of car'][i] = upper
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1858429955.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['Age of car'][i] = upper
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1858429955.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
sns.boxplot(df5['Age of car'])
# Out:
# <Axes: >

# %%
sns.distplot(df5['Age of car'])
# Out:
# C:\Users\Munjala Hari Krishna\AppData\Local\Temp\ipykernel_12724\1371151243.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df5['Age of car'])
# C:\Users\Munjala Hari Krishna\anaconda3\lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
df5['log_Price'] = np.log(df5['Price'])
df5.head(2)
# Out:
#      model  Age of car  engine_power transmission fuel_type      Price  \
# 0  octavia          20         147.0          man    petrol  543764.25
# 1    panda           7          51.0          man    petrol  401819.25
#
#    log_Price
# 0  13.206271
# 1  12.903758

# %%
plt.hist(df5.log_Price)
# Out:
# (array([1.5000e+01, 0.0000e+00, 1.0000e+00, 3.0000e+00, 3.0000e+00,
#         7.7000e+01, 2.7140e+03, 2.5380e+04, 2.5032e+04, 2.9000e+02]),
#  array([ 1.09861229,  2.67995384,  4.26129539,  5.84263694,  7.42397849,
#          9.00532004, 10.58666158, 12.16800313, 13.74934468, 15.33068623,
#         16.91202778]),
#  <BarContainer object of 10 artists>)

# %%
df5_numeric_features = df5.select_dtypes(include =[np.number])
df5_numeric_features.columns
# Out:
# Index(['Age of car', 'engine_power', 'Price', 'log_Price'], dtype='object')

# %%
df5_categorical_features = df5.select_dtypes(include =object)
df5_categorical_features.columns
# Out:
# Index(['model', 'transmission', 'fuel_type'], dtype='object')

# %%
df5_categorical_features.columns.values
# Out:
# array(['model', 'transmission', 'fuel_type'], dtype=object)

# %%
for col in df5_categorical_features.columns.values:
    dummy_encoded_variables5 = pd.get_dummies(df5_categorical_features[col], prefix = col, drop_first = True)
    df5_categorical_features = pd.concat([df5_categorical_features, dummy_encoded_variables5], axis = 1)
    df5_categorical_features.drop([col], axis=1, inplace = True)

# %%
df5_dummy = pd.concat([df5_numeric_features, df5_categorical_features], axis=1)

# %%
df5_dummy.head()
# Out:
#    Age of car  engine_power       Price  log_Price  model_avensis  model_aygo  \
# 0          20         147.0   543764.25  13.206271          False       False
# 1           7          51.0   401819.25  12.903758          False       False
# 2           5         105.0  2392855.50  14.687998          False       False
# 3           8         140.0   958606.50  13.773236          False       False
# 4           7         180.0  3085561.50  14.942244          False       False
#
#    model_citigo  model_coupe  model_i30  model_juke  ...  model_roomster  \
# 0         False        False      False       False  ...           False
# 1         False        False      False       False  ...           False
# 2         False        False      False       False  ...           False
# 3         False        False      False        True  ...           False
# 4         False        False      False       False  ...           False
#
# ...

# %%
x5 =df5_dummy.columns.values
len(x5)
# Out:
# 28

# %%
df5_train, df5_test = train_test_split(df5_dummy, random_state = 1)
print(df5_train.shape)
print(df5_test.shape)
# Out:
# (40136, 28)
# (13379, 28)

# %%
x_train5 = df5_train.drop(['Price', 'log_Price'], axis=1)
y_train5 = df5_train['Price']
lr5 = LinearRegression()
lr5.fit(x_train5, y_train5)
pd.DataFrame({'attribute':x_train5.columns, 'coeff':lr5.coef_})
# Out:
#            attribute         coeff
# 0         Age of car -1.028925e+05
# 1       engine_power  3.789261e+03
# 2      model_avensis  1.817702e+05
# 3         model_aygo -2.327964e+05
# 4       model_citigo -3.700459e+05
# 5        model_coupe  8.071863e+05
# 6          model_i30 -1.329640e+05
# 7         model_juke -7.980306e+04
# 8        model_micra  6.350312e+04
# 9      model_octavia  1.258358e+05
# 10       model_panda -6.621233e+04
# 11          model_q3  8.259519e+05
# 12          model_q5  9.386223e+05
# 13          model_q7  1.334828e+06
# 14     model_qashqai  2.093791e+05
# 15       model_rapid -1.482913e+05
# 16    model_roomster -3.093207e+04
# 17      model_superb  1.552458e+05
# 18          model_tt  8.198806e+05
# 19          model_x1  4.918521e+05
# 20          model_x3  7.676375e+05
# 21          model_x5  8.550508e+05
# 22       model_yaris -2.941029e+02
# 23        model_yeti  1.195445e+05
# 24  transmission_man -2.047228e+05
# 25  fuel_type_petrol -2.648586e+04

# %%
x_test5 = df5_test.drop(['Price', 'log_Price'], axis=1)
y_test5 = df5_test['Price']
y_pred_test5 = lr5.predict(x_test5)
rmsq_test5 = mean_squared_error(y_test5, y_pred_test5, squared = False)
rmsq_test5
# Out:
# 413001.4414918394

# %%
plt.scatter(y_test5, y_pred_test5)

# %%
y_pred_train5 = lr5.predict(x_train5)
rmsq_train5 = mean_squared_error(y_train5, y_pred_train5, squared = False)
rmsq_train5
# Out:
# 436489.09221226274

# %%
plt.scatter(y_train5, y_pred_train5)

# %%
x_train5_log = df5_train.drop(['Price','log_Price'], axis=1)
y_train5_log = df5_train['log_Price']
lr5_log = LinearRegression()
lr5_log.fit(x_train5_log, y_train5_log)
pd.DataFrame({'attribute':x_train5_log.columns, 'coeff':lr5_log.coef_})
# Out:
#            attribute     coeff
# 0         Age of car -0.133327
# 1       engine_power  0.004079
# 2      model_avensis  0.060055
# 3         model_aygo -0.392319
# 4       model_citigo -0.482744
# 5        model_coupe  0.498789
# 6          model_i30 -0.184567
# 7         model_juke -0.075976
# 8        model_micra -0.396903
# 9      model_octavia -0.009596
# 10       model_panda -0.343552
# 11          model_q3  0.469328
# 12          model_q5  0.583934
# 13          model_q7  0.643603
# 14     model_qashqai  0.194560
# 15       model_rapid -0.166017
# 16    model_roomster -0.125478
# 17      model_superb  0.100430
# 18          model_tt  0.603586
# 19          model_x1  0.376638
# 20          model_x3  0.540105
# 21          model_x5  0.565695
# 22       model_yaris -0.167409
# 23        model_yeti  0.113249
# 24  transmission_man -0.109929
# 25  fuel_type_petrol -0.052292

# %%
x_test5_log = df5_test.drop(['Price','log_Price'], axis=1)
y_test5_log = df5_test['log_Price']
y_pred_test5_log = lr5_log.predict(x_test5_log)
y_pred_test5_exp =np.exp(y_pred_test5_log)
rmsq_test5_exp = mean_squared_error(y_test5, y_pred_test5_exp, squared = False)
rmsq_test5_exp
# Out:
# 297415.77450361

# %%
plt.scatter(y_test5, y_pred_test5_exp)

# %%
y_pred_train5_log = lr5_log.predict(x_train5_log)
y_pred_train5_exp =np.exp(y_pred_train5_log)
rmsq_train5_exp = mean_squared_error(y_train5, y_pred_train5_exp, squared = False)
rmsq_train5_exp
# Out:
# 329393.39127154264
